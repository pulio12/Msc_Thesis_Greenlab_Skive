# %%
import os
print(os.listdir(os.getcwd()))
# Out:
# ['.git', '.venv', '.vscode', '2017_DK1_PowerProduction.xlsx', '2017_DK1_SpotSprice_Load.xlsx', '2019_Skive_SolarPV.csv', '2019_Skive_WindSpeeds.csv', '2024_DK1_PowerProduction.xlsx', '2024_DK1_SpotSprice_Load.xlsx', '2024_entsoe_DK1_elprices.csv', 'Elspotprices2021_2025.xlsx', 'find_string.py', 'fix_notebook.py', 'GasDailyBalancingPrice.xlsx', 'Graph_viz_Manual_Plotting.ipynb', 'network_graph.svg', 'onshore_wind_1979-2017.csv', 'pv_optimal.csv', 'Re_Ninja_PV_data_DK.csv', 'Re_Ninja_WindOnshore_data_DK.csv', 'Test_file.ipynb', 'Test_file2.ipynb', 'Test_File3.ipynb', 'topography.dot']

# %%
#pip install graphviz

# %%
import graphviz
from graphviz import Source

# %%
# Add your Conda environment Graphviz bin folder to PATH
os.environ["PATH"] += r";C:\Users\Pulin\anaconda3\envs\pypsa1\Graphviz\bin"
 
from graphviz import Source
 
# Then your normal code
dot_path = r"C:\Users\Pulin\Desktop\Msc_Thesis_Greenlab_Skive\topography.dot"
 
with open(dot_path) as f:
    dot_source = f.read()
 
graph = Source(dot_source, format="svg")
svg_path = graph.render("network_graph", cleanup=True)
 
print("SVG saved to:", svg_path)
# Out:
# SVG saved to: network_graph.svg
